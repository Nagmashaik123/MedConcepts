# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagmashaik123/MedConcepts/blob/main/emptyTweetsforConcepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('originalD_twADR.csv')
df
# Out:
#        Unnamed: 0  ...                            tw_phrases
# 0               0  ...                       still not tired
# 1               1  ...             I haven't eaten in 3 days
# 2               2  ...  can't remember the last time I slept
# 3               3  ...                           I feel like
# 4               4  ...                            depression
# ...           ...  ...                                   ...
# 50765       50765  ...                 had me in my feelings
# 50766       50766  ...                               itching
# 50767       50767  ...                  cigarette withdrawal
# 50768       50768  ...               tapering off prednisone
# 50769       50769  ...                                   NaN
#
# [50770 rows x 4 columns]

# %%
# Reads all the empty file names and add the CUI from the file name to the list
emptyTweetList=[]
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
for each_file in all_filenames:
    emptyTweetList.append(each_file[25:33])

print(emptyTweetList)

# %%
import csv
emptyTweetList = ['C0860207', 'C3251821', 'C0085614', 'C0438717', 'C0595877', 'C0521592', 'C0520679', 'C0860745', 'C0877203', 'C1263960', 'C0206062', 'C0154301', 'C0391839', 'C0476414', 'C0156404', 'C0235893', 'C0855333', 'C1096343', 'C0151904', 'C0031572', 'C2586050', 'C0340464', 'C0024137', 'C0235807', 'C0151586', 'C0744727', 'C0853336', 'C0151752', 'C0041349', 'C0231686', 'C0151882', 'C0006142', 'C0877014', 'C0151601', 'C0085680', 'C1608945', 'C0162835', 'C0520878', 'C0580531', 'C0027424', 'C0023467', 'C0855329', 'C0271738', 'C0002064', 'C0020545', 'C0264886', 'C0279563', 'C0085136', 'C0852792', 'C0852911', 'C0036346', 'C0155789', 'C0235827', 'C0235431', 'C0750197', 'C0522035', 'C0001127', 'C0853711', 'C0595928', 'C0239150', 'C0276141', 'C0877167', 'C0392171', 'C0920063', 'C0005959', 'C1963916', 'C0271240', 'C0750857', 'C0553731', 'C0920171', 'C0151477', 'C0235763', 'C3160889', 'C0853697', 'C0235919', 'C0233571', 'C0007860', 'C0151898', 'C0423602', 'C0020569', 'C0520966', 'C0549453', 'C0231274', 'C0085819', 'C0855217', 'C0234975', 'C0235667', 'C0151436', 'C0751495', 'C0011263', 'C1167686', 'C0340238', 'C0575090', 'C0541936', 'C0032781', 'C0238111', 'C0741494', 'C0017565', 'C0234535', 'C0151899', 'C0235774', 'C0852711', 'C0278488', 'C0438235', 'C0041981', 'C0549297', 'C0856882', 'C0029163', 'C3160888', 'C0744403', 'C0037278', 'C0522063', 'C0700225', 'C0232208', 'C0024141', 'C0741553', 'C0595883', 'C0595929', 'C0239940', 'C0520459', 'C0521161', 'C0233767', 'C0854082', 'C0549346', 'C0038436', 'C0035204', 'C0856695', 'C0151765', '', 'C0040580', 'C0033036', 'C0039591', 'C0699744', 'C0028768', 'C0151529', 'C0522055', 'C0919591', 'C0002395', 'C0853225', 'C0151883', 'C0035459', 'C0684249', 'C0235369', 'C0851536', 'C1609512', 'C0151905', 'C0851664', 'C0009326', 'C1112709', 'C0438215', 'C0852361', 'C0860210', 'C0423232', 'C0277589', 'C0750876', 'C0549433', 'C0235353', 'C0241442', 'C0235996', 'C0002878', 'C0151694', 'C0038986', 'C0423273', 'C0542052', 'C0151505', 'C0235168', 'C1735647', 'C0853644', 'C0277890', 'C1262013', 'C0028173', 'C0233633', 'C0151559', 'C0857980', 'C0242459', 'C1704321', 'C0031190', 'C0042514', 'C0026205', 'C0948281', 'C0085576', 'C0424790
365', 'C0553548', 'C0521509', 'C0236048', 'C0232288', 'C0856623', 'C0860654', 'C0151854', 'C0521591', 'C0553704', 'C0853026', 'C1142011', 'C0162119', 'C0085569', 'C0206061', 'C0041327', 'C0221742', 'C0033777', 'C0232744', 'C0521495', 'C0017551', 'C0281963', 'C1369037', 'C0151511', 'C0311468', 'C0025162', 'C0600260', 'C0877406', 'C0032776', 'C0852932', 'C0013928', 'C1262535', 'C0151478', 'C1609496', 'C0034933', 'C0235453', 'C0151878', 'C0577559', 'C0151205', 'C0235957', 'C0036689']

dict_from_csv={}
with open('originalD_twADR.csv', mode='r') as file:
    reader = csv.reader(file)
    dict_from_csv = {rows[1]:rows[2] for rows in reader}

dict_from_csv
# Out:
# {'CUIs': 'concepts',
#  'C0455769': 'Energy increased',
#  'C0003123': 'Anorexia',
#  'C0917801': 'Sleeplessness',
#  'C0022107': 'Irritable Mood',
#  'C0011570': 'Mental Depression',
#  'C1971624': 'Loss of appetite (finding)',
#  'C0424295': 'Hyperactive behavior',
#  'C0003467': 'Anxiety',
#  'C0233414': 'Disturbance in attention',
#  'C0020175': 'Hunger',
#  'C0043096': 'Body Weight decreased',
#  'C0009676': 'Confusion',
#  'C0011551': 'Depersonalization',
#  'C0344320': 'Vivid dreams',
#  'C0021053': 'Immune System Diseases',
#  'C0030193': 'Pain',
#  'C0013144': 'Drowsiness',
#  'C0041657': 'Unconscious State',
#  'C0085633': 'Mood swings',
#  'C0600104': 'Obsessive compulsive behavior',
#  'C0037317': 'Sleep disturbances',
#  'C0087169': 'Withdrawal Symptoms',
#  'C0917799': 'Hypersomnia',
#  'C0021368': 'Inflammation',
#  'C0033975': 'Psychotic Disorders',
#  'C0338614': 'Psychotic episode',
#  'C0040822': 'Tremor',
#  'C0520962': 'Pain localised',
# ...

# %%
conceptEmptyTweet = {}
for each in emptyTweetList:
  if each in dict_from_csv:
    conceptEmptyTweet[each]=dict_from_csv[each]

conceptEmptyTweet
# Out:
# {'': '',
#  'C0000727': 'Abdomen, Acute',
#  'C0000731': 'Abdomen distended',
#  'C0001127': 'Acidosis, Respiratory',
#  'C0001339': 'Pancreatitis acute',
#  'C0001396': 'Adams-Stokes Syndrome',
#  'C0001511': 'Tissue Adhesions',
#  'C0001622': 'Adrenal Gland Hyperfunction',
#  'C0001623': 'Adrenal gland hypofunction',
#  'C0002064': 'Alkalosis, Respiratory',
#  'C0002395': "Alzheimer's Disease",
#  'C0002878': 'Anemia, Hemolytic',
#  'C0002886': 'Anemia, Macrocytic',
#  'C0002888': 'Anemia, Megaloblastic',
#  'C0002965': 'Angina, Unstable',
#  'C0003868': 'Arthritis, Gouty',
#  'C0003872': 'Arthritis, Psoriatic',
#  'C0005587': 'Depression, Bipolar',
#  'C0005944': 'Metabolic Bone Disorder',
#  'C0005959': 'Marrow hyperplasia',
#  'C0006142': 'Malignant neoplasm of breast',
#  'C0006384': 'Bundle-Branch Block',
#  'C0006852': 'Candidiasis of vagina',
#  'C0007131': 'Non-Small Cell Lung Carcinoma',
#  'C0007193': 'Cardiomyopathy, Dilated',
#  'C0007860': 'Uterine Cervicitis',
# ...

# %%
df = pd.DataFrame(list(conceptEmptyTweet.items()), columns=['CUI', 'Concept'])
  
df.to_csv('emptyTweetConcepts.csv')
